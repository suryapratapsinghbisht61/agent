# %%
from langchain_community.chat_models import ChatOllama as ol 
llm=ol(
    model="gemma4:e2b"
)
res=llm.invoke("capital of france")
print(res.content)
# Out:
# Paris

# %% [markdown]
# for chains we can use two methods

# %%
chain= '''write steps iside this like step 1 | step 2 | step 3 etc like this '''

# %% [markdown]
# Another method is

# %%
from langchain_core.runnables import RunnableSequence as rs
chain1=rs#(step1,step2,step3)
#chain1.invoke("what is the capitel of france")

# %%
#CHAIN

# %%
from langchain_community.chat_models import ChatOllama as ol 
llm=ol(
    model="deepseek-r1:1.5b"
)
res=llm.invoke("what is the capital of france")
print(res.text)
# Out:
# The capital of France is Paris.
