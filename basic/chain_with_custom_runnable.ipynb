# %%
from langchain_core.runnables import RunnableLambda

# %%
# Example of a Custom Runnable using RunnableLambda
def add_enthusiasm(text: str) -> str:
    return f"{text}!!!"

chain = RunnableLambda(add_enthusiasm)

result = chain.invoke("Hello LangChain")
print(result)

# %%
# to butify the output

# %%
def butify(finalsesponse:dict)-> dict:

butify_rannable= RunnableLambda(butify)
